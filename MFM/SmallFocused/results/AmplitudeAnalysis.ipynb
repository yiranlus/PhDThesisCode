# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import proplot as pplt
from matplotlib_scalebar.scalebar import ScaleBar
from skimage.restoration import unwrap_phase

from itertools import product

# %% [markdown]
# ## inside the scan region

# %%
import glob

amps = dict()
prob_max = dict()
for i in glob.glob('*/final_trans*.npy'):
    if i.count('padding_1'):
        padding = 1
    else:
        padding = 2

    if i.count('ePIE'):
        alg = 'GEM ePIE'
    elif i.count('PtyPy_EPIE'):
        alg = 'PtyPy EPIE'
    else:
        alg = 'PtyPy DM'

    amps['{} {}'.format(alg, padding)] = np.abs(np.load(i))
    prob_max['{} {}'.format(alg, padding)] = np.sum(np.abs(np.load(i.replace('trans', 'probe')))**2)

# %%
prob_max
# Out:
# {'GEM ePIE 1': 0.46253395,
#  'GEM ePIE 2': 0.107728235,
#  'PtyPy DM 1': 6719.489,
#  'PtyPy DM 2': 6727.688,
#  'PtyPy EPIE 1': 10291.838,
#  'PtyPy EPIE 2': 3894562.8}

# %%
fig, axs = pplt.subplots(
    nrows=2, ncols=3, figwidth="14cm", sharex=False,
    xticks=[], yticks=[])

vmin = min([np.min(i) for i in amps.values()])
vmax = max([np.max(i) for i in amps.values()])
counter = 0
for ax, amp in zip(list(axs), product([1, 2], ['GEM ePIE', 'PtyPy DM', 'PtyPy EPIE'])):
    img = amps['{} {}'.format(*reversed(amp))]
    m = ax.imshow(img, vmin=vmin, vmax=vmax)
    if counter > 2:
        ax.format(title=f'NRMSE: {np.mean(np.abs(img - 1)): .4f}')
    else:
        ax.format(title=f'{amp[1]}\nNRMSE: {np.mean(np.abs(img - 1)): .4f}')
    counter += 1
fig.colorbar(m, loc='r', label='Amplitude')

fig.savefig('AmplitudeAnalysis.pdf')
# Out:
# Figure(nrows=2, ncols=3, figwidth=5.51)

# %%
vmin = min([np.min(i) for i in amps.values()])
vmax = max([np.max(i) for i in amps.values()])
vmin, vmax
# Out:
# (0.5660003, 1.2005566)

# %%
cycle
# Out:
# [[1, 2], [1, 2], [1, 2]]
